# %%
# !pip install -U openai-whisper
# !apt update && apt install -y ffmpeg

# %%
import whisper
model = whisper.load_model("base")
result = model.transcribe("/kaggle/input/voice-datas/T0003G4081S0007.wav")
print(result["text"])
